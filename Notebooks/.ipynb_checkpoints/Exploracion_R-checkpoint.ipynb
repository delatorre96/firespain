# %% [markdown]
# # Exploratory Analysis of Daily Burned Area in Spain (1983–2022)
#
# This notebook presents an exploratory analysis of a high-resolution spatial-temporal database on wildfires in Spain, spanning from January 2, 1983 to January 1, 2022. The database contains daily burned area estimates derived from satellite data and processed through the `climate4R` framework. The analysis is conducted using tools developed by the Santander Meteorology Group, an interdisciplinary research team from CSIC and Universidad de Cantabria, specializing in climate variability, downscaling and climate services.
#
# The notebook showcases simple but informative calculations to demonstrate the capabilities of the dataset and the climate4R ecosystem. The analysis includes spatial statistics, temporal trends, and spatial upscaling of burned area data. The goal is to provide a quick yet comprehensive overview of the potential of this dataset for fire-related research and spatial analysis.
#
# All steps are fully reproducible using `loadeR`, `transformeR`, and `visualizeR` packages.

# %%
library("loadeR")
library('transformeR')
library('visualizeR')
# Out:
# Cargando paquete requerido: rJava
#
# Cargando paquete requerido: loadeR.java
#
# Java version 1.8x amd64 by Oracle Corporation detected
#
# NetCDF Java Library v4.6.0-SNAPSHOT (23 Apr 2015) loaded and ready
#
# Cargando paquete requerido: climate4R.UDG
#
# climate4R.UDG version 0.2.6 (2023-06-26) is loaded
#
# Please use 'citation("climate4R.UDG")' to cite this package.
#
# loadeR version 1.8.2 (2024-06-04) is loaded
#
# Please use 'citation("loadeR")' to cite this package.
#     _______   ____  ___________________  __  ________
#    / ___/ /  / /  |/  / __  /_  __/ __/ / / / / __  /
#   / /  / /  / / /|_/ / /_/ / / / / __/ / /_/ / /_/_/
#  / /__/ /__/ / /  / / __  / / / / /__ /___  / / \ \
#  \___/____/_/_/  /_/_/ /_/ /_/  \___/    /_/\/   \_\
#
#       github.com/SantanderMetGroup/climate4R
# transformeR version 2.2.3 (2024-06-05) is loaded
#
# Please see 'citation("transformeR")' to cite this package.
#
# visualizeR version 1.6.4 (2023-10-26) is loaded
#
# Please see 'citation("visualizeR")' to cite this package.

# %% [markdown]
# ## Data Extraction

# %% [markdown]
# We start by loading the burned area dataset using `loadGridData` from the `loadeR` package. The result is a gridC4R object, which contains daily burned area data over Spain at a spatial resolution of 0.25 degrees.

# %%
grid_data <- loadGridData(dataset = "..\\raster_outputs\\r025\\firespain_025_WGS84_v0.3.nc", var = 'ba')
# Out:
# [2025-06-16 09:39:53.974586] Defining geo-location parameters
#
# [2025-06-16 09:39:54.069599] Defining time selection parameters
#
# [2025-06-16 09:39:54.307288] Retrieving data subset ...
#
# [2025-06-16 09:39:59.162691] Done

# %% [markdown]
# ## Spatial Statistics Computation

# %% [markdown]
# In this section, we compute basic spatial statistics over the entire time period. These aggregated values help summarize key characteristics of the burned area dataset and are visualized as spatial climatologies.

# %% [markdown]
# ### Mean Burned Area

# %% [markdown]
# Here, we compute the mean burned area per day at each pixel across the full time range. This highlights areas with recurrent or high-intensity fires.

# %%
ba_grid_025_agg <- aggregateGrid(grid = grid_data, aggr.y = list(FUN = 'mean', na.rm = TRUE))
spatialPlot(climatology(ba_grid_025_agg), backdrop.theme = 'coastline')
# Out:
# [2025-06-13 12:53:51.637847] Performing annual aggregation...
#
# [2025-06-13 12:53:54.086065] Done.
#
# [2025-06-13 12:53:54.104092] - Computing climatology...
#
# [2025-06-13 12:53:54.12393] - Done.
# plot without title

# %% [markdown]
# ### Total Wildfire Counts

# %% [markdown]
# Next, we compute the total number of wildfire events per pixel by counting the number of non-zero values over time. This provides insight into fire frequency.

# %%
ba_grid_025_agg <- aggregateGrid(grid = grid_data, aggr.y = list(FUN = function(x) sum(x > 0, na.rm = TRUE)))
spatialPlot(climatology(ba_grid_025_agg), backdrop.theme = 'coastline')
# Out:
# [2025-06-13 12:54:20.338333] Performing annual aggregation...
#
# [2025-06-13 12:54:21.859719] Done.
#
# [2025-06-13 12:54:21.878664] - Computing climatology...
#
# [2025-06-13 12:54:21.898916] - Done.
# plot without title

# %% [markdown]
# ### Wildfire Relative Frequency

# %% [markdown]
# We calculate the relative frequency of wildfires at each pixel, expressed as the ratio of days with fire occurrence to the total number of days. This metric gives a normalized measure of fire recurrence.

# %%
ba_grid_025_agg <- aggregateGrid(grid = grid_data, aggr.y = list(FUN = function(x) mean(x > 0, na.rm = TRUE)))
spatialPlot(climatology(ba_grid_025_agg), backdrop.theme = 'coastline')
# Out:
# [2025-06-13 12:54:49.416428] Performing annual aggregation...
#
# [2025-06-13 12:54:51.906425] Done.
#
# [2025-06-13 12:54:51.925328] - Computing climatology...
#
# [2025-06-13 12:54:51.948091] - Done.
# plot without title

# %% [markdown]
# ## Convert the grid into a DataFrame

# %%
start <- proc.time()
lon <- grid_data$xyCoords$x
lat <- grid_data$xyCoords$y
grid_df <- expand.grid(
  lat = lat,
  lon = lon
)
grid_df_list = list()
for (row in 1:nrow(grid_df)){
    subGridPixel <- subsetSpatial(grid_data, lonLim = grid_df[1,'lon'],  latLim = grid_df[1,'lat'])
    temporalSerie <- data.frame(
        lat = grid_df[row,'lat'],
        lon = grid_df[row,'lon'],
      date = as.Date(subGridPixel$Dates$start),
      ba = as.vector(subGridPixel$Data)
        )
    grid_df_list[[row]] <- temporalSerie
}
grid_df <- do.call(rbind, grid_df_list)
end <- proc.time()
elapsed <- end - start
elapsed["elapsed"]
# Out:
# elapsed
#  594.79

# %% [markdown]
# ## Temporal Evolution of Burned Area

# %% [markdown]
# This section focuses on the temporal dynamics of burned area. We explore how the area burned by wildfires evolves over time at both local and national scales.

# %% [markdown]
# ### Pixel-Level Time Series

# %% [markdown]
# We extract and plot the time series of a single pixel located in Galicia, a region known for frequent wildfire activity. This illustrates how burned area varies locally across the decades.

# %%
subGridPixel <- subsetSpatial(grid_data,lonLim = -8.135,  latLim = 42.351L)

# %%
temporalSerie <- data.frame(
  date = as.Date(subGridPixel$Dates$start),
  ba = as.vector(subGridPixel$Data)
)

# %%
plot(
  temporalSerie$date,
  temporalSerie$ba,
  type = "l",
  col = "firebrick",
  xlab = "Date",
  ylab = "Burned Area (ha)",
  main = "Burned Area Time Series"
)
# Out:
# Plot with title "Burned Area Time Series"

# %% [markdown]
# ### National Time Series

# %% [markdown]
# We compute the total burned area in Spain per day by summing all pixels. The resulting time series reveals long-term trends, seasonality, and interannual variability in wildfire activity.

# %%
temporalSerie_spain <- aggregateGrid(grid_data, aggr.lat = list(FUN = "sum", na.rm = TRUE), aggr.lon = list(FUN = "sum", na.rm = TRUE))
temporalSerie_spain_df <- data.frame(
  date = as.Date(temporalSerie_spain$Dates$start),
  ba = as.vector(temporalSerie_spain$Data)
)
# Out:
# Calculating areal weights...
#
# [2025-06-13 13:49:07.226196] - Aggregating lat dimension...
#
# [2025-06-13 13:49:09.082725] - Done.
#
# [2025-06-13 13:49:09.085179] - Aggregating lon dimension...
#
# [2025-06-13 13:49:09.128026] - Done.

# %%
plot(
  temporalSerie_spain_df$date,
  temporalSerie_spain_df$ba,
  type = "l",
  col = "firebrick",
  xlab = "Date",
  ylab = "Burned Area (ha)",
  main = "Burned Area Time Series"
)
# Out:
# Plot with title "Burned Area Time Series"

# %% [markdown]
# ## Spatial Upscaling

# %% [markdown]
# Finally, we perform spatial upscaling of the original 0.25° grid to coarser resolutions (0.5°, 1°, and 1.5°) using the `upscaleGrid` function. We apply the sum function to preserve total burned area values. We then visualize each upscaled version using mean climatologies to compare the impact of spatial resolution on the data representation.

# %%
ba_grid_05 <- upscaleGrid(grid = grid_data, times = 2, aggr.fun = list(FUN = sum, na.rm = TRUE))
ba_grid_1 <- upscaleGrid(grid = grid_data, times = 4, aggr.fun = list(FUN = sum, na.rm = TRUE))
ba_grid_15 <- upscaleGrid(grid = grid_data, times = 6, aggr.fun = list(FUN = sum, na.rm = TRUE))

# %%
ba_grid_025_agg <- aggregateGrid(grid = grid_data, aggr.y = list(FUN = 'mean', na.rm = TRUE))
ba_grid_05_agg <- aggregateGrid(grid = ba_grid_05, aggr.y = list(FUN = 'mean', na.rm = TRUE))
ba_grid_1_agg <- aggregateGrid(grid = ba_grid_1, aggr.y = list(FUN = 'mean', na.rm = TRUE))
ba_grid_15_agg <- aggregateGrid(grid = ba_grid_15, aggr.y = list(FUN = 'mean', na.rm = TRUE))
# Out:
# [2025-06-13 13:23:05.690816] Performing annual aggregation...
#
# [2025-06-13 13:23:08.19954] Done.
#
# [2025-06-13 13:23:08.289593] Performing annual aggregation...
#
# [2025-06-13 13:23:08.96782] Done.
#
# [2025-06-13 13:23:09.032354] Performing annual aggregation...
#
# [2025-06-13 13:23:09.19785] Done.
#
# [2025-06-13 13:23:09.2531] Performing annual aggregation...
#
# [2025-06-13 13:23:09.510679] Done.

# %%
spatialPlot(climatology(ba_grid_025_agg), backdrop.theme = 'coastline')
spatialPlot(climatology(ba_grid_05_agg), backdrop.theme = 'coastline')
spatialPlot(climatology(ba_grid_1_agg), backdrop.theme = 'coastline')
spatialPlot(climatology(ba_grid_15_agg), backdrop.theme = 'coastline')
# Out:
# [2025-06-13 13:23:18.912615] - Computing climatology...
#
# [2025-06-13 13:23:18.937758] - Done.
#
# [2025-06-13 13:23:19.089504] - Computing climatology...
#
# [2025-06-13 13:23:19.097745] - Done.
# plot without title
# [2025-06-13 13:23:19.336244] - Computing climatology...
#
# [2025-06-13 13:23:19.342258] - Done.
# plot without title
# [2025-06-13 13:23:19.574577] - Computing climatology...
#
# [2025-06-13 13:23:19.579744] - Done.
# plot without title
# plot without title
